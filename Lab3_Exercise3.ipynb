# %% [markdown]
# # I. Matplotlib

# %% [markdown]
# 1. Importing

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# 2. Basic Example

# %%
import numpy as np
x= np.linspace(0,5,11)
y=x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %% [markdown]
# 3 Basic Matplotlin Commands

# %%
plt.plot(x,y,'r') #'r is the color red
plt.xlabel("X Axis Title Here")
plt.ylabel("Y Axis Title Here")
plt.title("String Title Here")
plt.show()

# %% [markdown]
# 4. Creatring Multiplots on Same Canvas

# %%
#plt.subplot(nrows, ncols, plot_number)
plt.subplot(1,2,1)
plt.plot(x,y,'r--') #More on clor options later
plt.plot(y,x,'g*-');

# %% [markdown]
# 5 Oject Oriente Method

# %%
#Create Figure(empty canvas)
fig =plt.figure()

#Add set of axes to figure
axes = fig.add_axes([0.1,0.1,0.8,0.8])

#Plot on taht set of axes
axes.plot(x,y,'b')
axes.set_xlabel('Set X Label') # Notice the use of set_to begin
axes.set_ylabel('Set y label')
axes.set_title('Set Title')
# Out:
# Text(0.5, 1.0, 'Set Title')

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.8]) #main axes
axes2 = fig.add_axes([0.2,0.5,0.4,0.3]) #inset axes

#Larger Figure Axes 1
axes1.plot(x,y,'b')
axes1.set_xlabel('X_label_axes2')
axes1.set_ylabel('Y_label_axes2')
axes1.set_title('Axes 2 Title'
)

#Inset Figure Axes 2
axes2.plot(y,x,'r')
axes2.set_xlabel('X_label_axes2')
axes2.set_ylabel('Y_label_axes2')
axes2.set_title('Axes 2 Title')
# Out:
# Text(0.5, 1.0, 'Axes 2 Title')

# %% [markdown]
# 6. Subplot()

# %%
#Use similar to plt.figure() except use tuple unpacking to grab fig and axis

fig,axes = plt.subplots()

#Now use the axes object to add stuff to plot
axes.plot(x,y, 'y')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %%
#Empty canvas of 1 by 2 subplots
fig, axes = plt.subplots(nrows= 1, ncols =2)

# %%
axes
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
for ax in axes:
  ax.plot(x,y,'b')
  ax.set_xlabel('x')
  ax.set_ylabel('y')
  ax.set_title('title')
#Display the figure object
fig

# %%
fig,axes = plt.subplots(nrows=1, ncols=2)

for ax in axes:
  ax.plot(x,y,'g')
  ax.set_xlabel('x')
  ax.set_ylabel(y)
  ax.set_title('title')

fig
plt.tight_layout()
# Out:
# /usr/local/lib/python3.9/dist-packages/matplotlib/text.py:1279: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
fig = plt.figure(figsize=(8,4), dpi=100)

# %%
fig,axes = plt.subplots(figsize=(12,3))
axes.plot(x,y,'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title');

# %% [markdown]
# 8.Saving Figures

# %%
fig.savefig("filenames.png")

# %%
fig.savefig("filenames.png", dpi=200)

# %% [markdown]
# 9.Figure titles

# %%
ax.set_title("title");

# %% [markdown]
# 10 Axis labels

# %%
ax.set_xlabel("x")
ax.set_ylabel("y");

# %% [markdown]
# 11.Legends

# %%
fig = plt.figure()

ax=fig.add_axes([0,0,1,1])

ax.plot(x,x**2,label="x**2")
ax.plot(x,x**3, label="x**3")
ax.legend()

# %% [markdown]
# 12. Plot range

# %%
fig,axes = plt.subplots(1,3, figsize=(12,4))

axes[0].plot(x,x**2, x**3)
axes[0].set_title("default axes ranges")

axes[1].plot(x, x**2, x**3)
axes[1].axis('tight')
axes[1].set_title("tight axes")

axes[2].plot(x,x**2, x, x**3)
axes[2].set_ylim([0,60])
axes[2].set_xlim([2,5])
axes[2].set_title("custom axes range");

# %% [markdown]
# # II. Seaborn

# %% [markdown]
# 1. Load testing dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
# %matplotlib inline

sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# 2.Scatter plot

# %%
ax = sns.scatterplot(x="total_bill", y="tip", data=tips)

# %%
sns.relplot(x="total_bill", y="tip", data=tips, kind="scatter", hue="sex", size="size")

# %% [markdown]
# 3. Categorical functions

# %%
sns.catplot(x="sex", y="total_bill", hue="day", data=tips, kind="strip")

# %%
sns.catplot(x="sex", y="total_bill", hue="day", data=tips, kind="strip", jitter=False, dodge=True)

# %%
sns.catplot(x="sex", y="total_bill", hue="day", data=tips, kind="box")

# %% [markdown]
# # Exercise

# %% [markdown]
# 1. Job Market

# %%
df = pd.read_csv('/content/drive/MyDrive/job-market (1).csv')
df.head(10)
# Out:
#            Id                                              Title  \
# 0  37404348.0                           Casual Stock Replenisher
# 1  37404337.0                           Casual Stock Replenisher
# 2  37404356.0  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3  37404330.0                              Team member - Belrose
# 4  37404308.0  Business Banking Contact Centre Specialist, Ni...
# 5  37404307.0  Business Banking Contact Centre Specialist, Ni...
# 6  37404355.0               Casual Café All-rounder in Semaphore
# 7  37404350.0           Casual Café All-rounder in Woolloongabba
# 8  37404301.0                                       Telemarketer
# 9  37404286.0                       Casual Dish Hand in Brighton
#
#                                           Company                      Date  \
# 0                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 1                                     Aldi Stores  2018-10-07T00:00:00.000Z
# ...

# %%
df.dtypes
# Out:
# Id                   float64
# Title                 object
# Company               object
# Date                  object
# Location              object
# Area                  object
# Classification        object
# SubClassification     object
# Requirement           object
# FullDescription       object
# LowestSalary         float64
# HighestSalary        float64
# JobType               object
# dtype: object

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=df.drop_duplicates()
df=df.dropna()
df.isnull().sum()
# Out:
# Id                   0
# Title                0
# Company              0
# Date                 0
# Location             0
# Area                 0
# Classification       0
# SubClassification    0
# Requirement          0
# FullDescription      0
# LowestSalary         0
# HighestSalary        0
# JobType              0
# dtype: int64

# %%
location_counts = df['Location'].value_counts()

# %%
bar = df['Location'].value_counts().index

# %%
print(location_counts)
# Out:
# Sydney       2382
# Melbourne    2094
# Brisbane      900
# Perth         522
# Name: Location, dtype: int64

# %%
# Create bar chart
plt.figure(figsize=(8,8))
sns.countplot(data=df, y=df['Location'], order=bar)



# Add title and labels
plt.title('Number of Job by Location')
plt.xlabel('Num of Jobs')
plt.ylabel('Classification')

# Display chart
plt.show()

# %% [markdown]
# 2. Salary Range

# %%
df1=df['LowestSalary']
df2=df['HighestSalary']

# %%
df['salary_mean'] = (df['LowestSalary'] + df['HighestSalary']) / 2

# %%
#Phân loại dữ liệu thành 4 khoảng giá trị
bins = [0, 30, 40, 50,np.inf]
labels = ['0-30', '30-40', '40-50', '50-60']
df['salary_range'] = pd.cut(df['salary_mean'], bins=bins, labels=labels)

# %%
## Đếm số lượng mục trong mỗi khoảng giá trị
counts = df['salary_range'].value_counts()

# %%
# Vẽ đồ thị đường tròn
fig, ax = plt.subplots()
ax.pie(counts.values, labels=counts.index)
# Vẽ đường tròn giữa để tạo thành đồ thị đường tròn
centre_circle = plt.Circle((0, 0), 0.3, color='white')
fig.gca().add_artist(centre_circle)

# %% [markdown]
# 2. Data Correlation (Advanced and Optional)

# %%
df = pd.read_csv('/content/drive/MyDrive/wine.data.csv')
df.head(10)
# Out:
#    Label  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
# 5      1    14.20        1.76  2.45               15.2        112
# 6      1    14.39        1.87  2.45               14.6         96
# 7      1    14.06        2.15  2.61               17.6        121
# 8      1    14.83        1.64  2.17               14.0         97
# 9      1    13.86        1.35  2.27               16.0         98
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# ...

# %%
labels = df.pop('Label')
df.head(10)
# Out:
#    Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0    14.23        1.71  2.43               15.6        127           2.80
# 1    13.20        1.78  2.14               11.2        100           2.65
# 2    13.16        2.36  2.67               18.6        101           2.80
# 3    14.37        1.95  2.50               16.8        113           3.85
# 4    13.24        2.59  2.87               21.0        118           2.80
# 5    14.20        1.76  2.45               15.2        112           3.27
# 6    14.39        1.87  2.45               14.6         96           2.50
# 7    14.06        2.15  2.61               17.6        121           2.60
# 8    14.83        1.64  2.17               14.0         97           2.80
# 9    13.86        1.35  2.27               16.0         98           2.98
#
#    Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# ...

# %%
sns.pairplot(df)

# %%
# Create the correlation matrix
corr_matrix = df.corr()

# Create the heatmap
sns.heatmap(corr_matrix, cmap='coolwarm', annot=True)
# Out:
# <Axes: >
